# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
st1 = pd.read_csv('/content/SalaryData_Test.csv')
st2=pd.read_csv('/content/SalaryData_Train.csv')

# %%
st1 = st1.drop_duplicates()
st1
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
st1.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  14130.000000  14130.000000  14130.000000  14130.000000  14130.000000
# mean      39.155414     10.120736   1185.899292     94.499646     41.073885
# std       13.429544      2.602557   7903.191981    417.955786     12.268036
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       29.000000      9.000000      0.000000      0.000000     40.000000
# 50%       38.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
# Label encoding

# %%
#@title Label Encoding
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
st1['workclass']= label_encoder.fit_transform(st1['workclass'])
st1['education']= label_encoder.fit_transform(st1['education'])
st1['maritalstatus']= label_encoder.fit_transform(st1['maritalstatus'])
st1['occupation']= label_encoder.fit_transform(st1['occupation'])
st1['relationship']= label_encoder.fit_transform(st1['relationship'])
st1['race']= label_encoder.fit_transform(st1['race'])
st1['sex']= label_encoder.fit_transform(st1['sex'])
st1['native']= label_encoder.fit_transform(st1['native'])
st1['Salary']= label_encoder.fit_transform(st1['Salary'])

# %%
st1
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
st1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14130 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            14130 non-null  int64
#  1   workclass      14130 non-null  int64
#  2   education      14130 non-null  int64
#  3   educationno    14130 non-null  int64
#  4   maritalstatus  14130 non-null  int64
#  5   occupation     14130 non-null  int64
#  6   relationship   14130 non-null  int64
#  7   race           14130 non-null  int64
#  8   sex            14130 non-null  int64
#  9   capitalgain    14130 non-null  int64
#  10  capitalloss    14130 non-null  int64
#  11  hoursperweek   14130 non-null  int64
#  12  native         14130 non-null  int64
#  13  Salary         14130 non-null  int64
# dtypes: int64(14)
# memory usage: 1.6 MB

# %%
st1.shape
# Out:
# (14130, 14)

# %%
st1.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
#sns.pairplot(st1,hue='Salary')

# %%
plt.figure(figsize=(18,8))
sns.heatmap(st1.corr(),cmap='magma',annot=True)
# Out:
# <Axes: >

# %%
sns.distplot(st1['hoursperweek'])
plt.show()
# Out:
# <ipython-input-11-cb0788c0cc26>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(st1['hoursperweek'])

# %%
sns.barplot(x=st1.age,y=st1.educationno)
# Out:
# <Axes: xlabel='age', ylabel='educationno'>

# %%
sns.regplot(x=st1['age'],y=st1['hoursperweek'])
# Out:
# <Axes: xlabel='age', ylabel='hoursperweek'>

# %%
#Test DataSet
st2 = st2.drop_duplicates()
st2
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 30154   53            Private        Masters           14
# 30155   22            Private   Some-college           10
# 30156   27            Private     Assoc-acdm           12
# 30158   58            Private        HS-grad            9
# 30160   52       Self-emp-inc        HS-grad            9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#@title Label Encoding
st2['workclass']= label_encoder.fit_transform(st2['workclass'])
st2['education']= label_encoder.fit_transform(st2['education'])
st2['maritalstatus']= label_encoder.fit_transform(st2['maritalstatus'])
st2['occupation']= label_encoder.fit_transform(st2['occupation'])
st2['relationship']= label_encoder.fit_transform(st2['relationship'])
st2['race']= label_encoder.fit_transform(st2['race'])
st2['sex']= label_encoder.fit_transform(st2['sex'])
st2['native']= label_encoder.fit_transform(st2['native'])
st2['Salary']= label_encoder.fit_transform(st2['Salary'])

st2
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30154   53          2         12           14              2           3
# 30155   22          2         15           10              4          10
# 30156   27          2          7           12              2          12
# 30158   58          2         11            9              6           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
st2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26903 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            26903 non-null  int64
#  1   workclass      26903 non-null  int64
#  2   education      26903 non-null  int64
#  3   educationno    26903 non-null  int64
#  4   maritalstatus  26903 non-null  int64
#  5   occupation     26903 non-null  int64
#  6   relationship   26903 non-null  int64
#  7   race           26903 non-null  int64
#  8   sex            26903 non-null  int64
#  9   capitalgain    26903 non-null  int64
#  10  capitalloss    26903 non-null  int64
#  11  hoursperweek   26903 non-null  int64
#  12  native         26903 non-null  int64
#  13  Salary         26903 non-null  int64
# dtypes: int64(14)
# memory usage: 3.1 MB

# %%
st2.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
#sns.pairplot(st2,hue='Salary')

# %%
plt.figure(figsize = (21, 7));
sns.heatmap(st2.corr(), cmap='magma', annot=True)
plt.show()

# %%
#@title performing train test split
x_train = st1.iloc[:,0:13]
y_train = st1.iloc[:,-1]   #last column is -1
x_test = st2.iloc[:,0:13]
y_test = st2.iloc[:,-1]

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((14130, 13), (14130,), (26903, 13), (26903,))

# %%
#@title Multinomial NB
from sklearn.naive_bayes import MultinomialNB as MB

# %%
classifier_mb = MB()
classifier_mb.fit(x_train,y_train)     # Model Train
# Out:
# MultinomialNB()

# %%
# Model Accuracy on train set
train_pred_m = classifier_mb.predict(x_train)
accuracy_train_m = np.mean(train_pred_m==y_train)

# %%
# Model Accuracy on test set
test_pred_m = classifier_mb.predict(x_train)
accuracy_test_m = np.mean(test_pred_m==y_train)

# %%
accuracy_train_m
# Out:
# 0.7733899504600141

# %%
accuracy_test_m
# Out:
# 0.7733899504600141

# %%
#@title CategoricalNB
from sklearn.naive_bayes import CategoricalNB as CNB

# %%
classifier_cnb = CNB()
classifier_cnb.fit(x_train,y_train)    # Model Train
# Out:
# CategoricalNB()

# %%
# Model Accuracy on train set
train_pred_cnb = classifier_cnb.predict(x_train)
accuracy_train_cnb = np.mean(train_pred_cnb==y_train)

# %%
# Model Accuracy on test set
test_pred_cnb = classifier_cnb.predict(x_train)
accuracy_test_cnb = np.mean(test_pred_cnb==y_train)

# %%
accuracy_test_cnb
# Out:
# 0.8544939844302901

# %%
accuracy_train_cnb
# Out:
# 0.8544939844302901

# %%
#@title GaussianNB
from sklearn.naive_bayes import GaussianNB as GB

# %%
classifier_gb = GB()
classifier_gb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
# Model Accuracy on train set
train_pred_g = classifier_gb.predict(x_train)
accuracy_train_g = np.mean(train_pred_g==y_train)

# %%
# Model Accuracy on test set
test_pred_g = classifier_gb.predict(x_train)
accuracy_test_g = np.mean(test_pred_g==y_train)

# %%
accuracy_train_g
# Out:
# 0.7940552016985138

# %%
accuracy_test_g
# Out:
# 0.7940552016985138

# %%
#Inference: Categorical Naive Bayes gives us better Accuracy which is about 85.39%
